# %% [markdown]
# Task_5- To explore Business Analytics

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("SampleSuperstore.csv")

# %%
print("Import Super-store Data--")
df
# Out:
# Import Super-store Data--
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
#       Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0           42420  South        Furniture    Bookcases  261.9600         2
# 1           42420  South        Furniture       Chairs  731.9400         3
# 2           90036   West  Office Supplies       Labels   14.6200         2
# 3           33311  South        Furniture       Tables  957.5775         5
# 4           33311  South  Office Supplies      Storage   22.3680         2
# ...           ...    ...              ...          ...       ...       ...
# 9989        33180  South        Furniture  Furnishings   25.2480         3
# 9990        92627   West        Furniture  Furnishings   91.9600         2
# 9991        92627   West       Technology       Phones  258.5760         2
# 9992        92627   West  Office Supplies        Paper   29.6000         4
# 9993        92683   West  Office Supplies   Appliances  243.1600         2
#
#       Discount    Profit
# 0         0.00   41.9136
# 1         0.00  219.5820
# 2         0.00    6.8714
# 3         0.45 -383.0310
# 4         0.20    2.5164
# ...        ...       ...
# 9989      0.20    4.1028
# 9990      0.00   15.6332
# 9991      0.20   19.3932
# 9992      0.00   13.3200
# 9993      0.00   72.9480
#
# [9994 rows x 13 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
df.shape
# Out:
# (9994, 13)

# %%
df.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %% [markdown]
# ->Finding Error or null value in data and solve it-

# %%
pd.DataFrame( df.isnull().sum(), columns= ['Number of missing values'])
# Out:
#               Number of missing values
# Ship Mode                            0
# Segment                              0
# Country                              0
# City                                 0
# State                                0
# Postal Code                          0
# Region                               0
# Category                             0
# Sub-Category                         0
# Sales                                0
# Quantity                             0
# Discount                             0
# Profit                               0

# %% [markdown]
# According to upper table we see they have not an error or null value in data

# %%
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
df.corr()
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023854  0.012761  0.058443 -0.029961
# Sales          -0.023854  1.000000  0.200795 -0.028190  0.479064
# Quantity        0.012761  0.200795  1.000000  0.008623  0.066253
# Discount        0.058443 -0.028190  0.008623  1.000000 -0.219487
# Profit         -0.029961  0.479064  0.066253 -0.219487  1.000000

# %%
import seaborn as sns
sns.heatmap(df.corr(), annot=True)

# %% [markdown]
# As we see Correlation in 'Sales & Profit' and 'Sales & Quantity' is Majore-

# %% [markdown]
# -> So Now we Analysis Data's-

# %%
sns.scatterplot(df['Profit'], df['Sales'], hue=df['Region'], palette='Set2')

# %%
df['Region'].value_counts()
# Out:
# West       3203
# East       2848
# Central    2323
# South      1620
# Name: Region, dtype: int64

# %% [markdown]
# As Above Data tells the Demand by Region

# %%
df['Quantity'].value_counts()
# Out:
# 3     2409
# 2     2402
# 5     1230
# 4     1191
# 1      899
# 7      606
# 6      572
# 9      258
# 8      257
# 10      57
# 11      34
# 14      29
# 13      27
# 12      23
# Name: Quantity, dtype: int64

# %% [markdown]
# As Above Data tells the Maximum Demanding Quantity

# %% [markdown]
# ->Now let's Make Grafe between Sales-Quantity and Quantity-Profit-

# %%
sns.scatterplot(df['Quantity'], df['Sales'], hue=df['Region'], palette='Set2')

# %%
sns.scatterplot( df['Profit'],df['Quantity'], hue=df['Region'], palette='Set2')

# %% [markdown]
# As We see above that No Profit in company in Quantity 1 to 8.

# %%
sns.boxplot('Discount','Profit', data=df)

# %% [markdown]
# As We see above that No Profit in company when Discount is above 40%.

# %%
t=pd.DataFrame(np.percentile(df['Profit'],[25,40,60,80,90,99.5],axis=0)).transpose()
t.columns=['Prce_20','Prce_40','Prce_60','Prce_80','Prce_90','Prce_99.5']

# %%
t
# Out:
#    Prce_20  Prce_40  Prce_60  Prce_80   Prce_90  Prce_99.5
# 0  1.72875   5.4432  13.4913  41.0388  89.28162   843.1706

# %%
GP1=df.groupby(['Region']).Profit.mean().reset_index()
GP1
# Out:
#     Region     Profit
# 0  Central  17.092709
# 1     East  32.135808
# 2    South  28.857673
# 3     West  33.849032

# %%
GP1.sort_values("Profit", axis = 0, ascending = False, 
                 inplace = True, na_position ='first') 
GP_1=GP1.reset_index()
GP_1.drop(['index'], axis = 1)
# Out:
#     Region     Profit
# 0     West  33.849032
# 1     East  32.135808
# 2    South  28.857673
# 3  Central  17.092709

# %%
import matplotlib.pyplot as plt
plt.barh(GP_1['Region'],GP_1['Profit'])
plt.xlabel('PROFIT')
plt.ylabel('FROM REGION')
plt.show()

# %% [markdown]
# As we see above Less Profit in Central Region so need to improve it

# %%
GP2=df.groupby(['Quantity']).Profit.mean().reset_index()
GP2
# Out:
#     Quantity      Profit
# 0          1    8.276396
# 1          2   16.006831
# 2          3   23.667715
# 3          4   37.131310
# 4          5   40.257394
# 5          6   18.051517
# 6          7   56.579163
# 7          8   42.244342
# 8          9   68.557716
# 9         10   35.862404
# 10        11  126.275503
# 11        12   51.524609
# 12        13  235.144481
# 13        14   93.931166

# %%
GP2.sort_values("Profit", axis = 0, ascending = False, 
                 inplace = True, na_position ='first') 
GP_2=GP2.reset_index()
GP_2.drop(['index'], axis = 1)
# Out:
#     Quantity      Profit
# 0         13  235.144481
# 1         11  126.275503
# 2         14   93.931166
# 3          9   68.557716
# 4          7   56.579163
# 5         12   51.524609
# 6          8   42.244342
# 7          5   40.257394
# 8          4   37.131310
# 9         10   35.862404
# 10         3   23.667715
# 11         6   18.051517
# 12         2   16.006831
# 13         1    8.276396

# %%
plt.barh(GP_2['Quantity'],GP_2['Profit'])
plt.xlabel('Profit Gain from Product')
plt.ylabel('Quantity of Product')
plt.show()

# %% [markdown]
# As We See Quantity 1 to 6 as not given good profit to company

# %%
GP3=df.groupby(['State']).Profit.mean().reset_index()
GP3
# Out:
#                    State      Profit
# 0                Alabama   94.865989
# 1                Arizona  -15.303235
# 2               Arkansas   66.811452
# 3             California   38.171608
# 4               Colorado  -35.867351
# 5            Connecticut   42.823071
# 6               Delaware  103.930988
# 7   District of Columbia  105.958930
# 8                Florida   -8.875461
# 9                Georgia   88.315453
# 10                 Idaho   39.367767
# 11              Illinois  -25.625787
# 12               Indiana  123.375411
# 13                  Iowa   39.460397
# 14                Kansas   34.851813
# 15              Kentucky   80.573357
# 16             Louisiana   52.288150
# 17                 Maine   56.810775
# 18              Maryland   66.963608
# 19         Massachusetts   50.262975
# 20              Michigan   95.934069
# 21             Minnesota  121.608847
# 22           Mississippi   59.867475
# 23              Missouri   97.518341
# 24               Montana  122.221900
# 25              Nebraska   53.607742
# 26                Nevada   85.045279
# 27         New Hampshire   63.203807
# 28            New Jersey   75.176260
# 29            New Mexico   31.273408
# 30              New York   65.637011
# 31        North Carolina  -30.083985
# 32          North Dakota   32.878529
# 33                  Ohio  -36.186304
# 34              Oklahoma   73.544788
# 35                Oregon   -9.600569
# 36          Pennsylvania  -26.507598
# 37          Rhode Island  130.100523
# 38        South Carolina   42.120395
# 39          South Dakota   32.902358
# 40             Tennessee  -29.189583
# 41                 Texas  -26.121174
# 42                  Utah   48.047802
# 43               Vermont  204.088936
# 44              Virginia   83.026564
# 45            Washington   66.013146
# 46         West Virginia   46.480400
# 47             Wisconsin   76.380004
# 48               Wyoming  100.196000

# %%
#arreng in asending oder
GP3.sort_values("Profit", axis = 0, ascending = False, 
                 inplace = True, na_position ='first') 
GP_3=GP3.reset_index()
GP_3.drop(['index'], axis = 1)
# Out:
#                    State      Profit
# 0                Vermont  204.088936
# 1           Rhode Island  130.100523
# 2                Indiana  123.375411
# 3                Montana  122.221900
# 4              Minnesota  121.608847
# 5   District of Columbia  105.958930
# 6               Delaware  103.930988
# 7                Wyoming  100.196000
# 8               Missouri   97.518341
# 9               Michigan   95.934069
# 10               Alabama   94.865989
# 11               Georgia   88.315453
# 12                Nevada   85.045279
# 13              Virginia   83.026564
# 14              Kentucky   80.573357
# 15             Wisconsin   76.380004
# 16            New Jersey   75.176260
# 17              Oklahoma   73.544788
# 18              Maryland   66.963608
# 19              Arkansas   66.811452
# 20            Washington   66.013146
# 21              New York   65.637011
# 22         New Hampshire   63.203807
# 23           Mississippi   59.867475
# 24                 Maine   56.810775
# 25              Nebraska   53.607742
# 26             Louisiana   52.288150
# 27         Massachusetts   50.262975
# 28                  Utah   48.047802
# 29         West Virginia   46.480400
# 30           Connecticut   42.823071
# 31        South Carolina   42.120395
# 32                  Iowa   39.460397
# 33                 Idaho   39.367767
# 34            California   38.171608
# 35                Kansas   34.851813
# 36          South Dakota   32.902358
# 37          North Dakota   32.878529
# 38            New Mexico   31.273408
# 39               Florida   -8.875461
# 40                Oregon   -9.600569
# 41               Arizona  -15.303235
# 42              Illinois  -25.625787
# 43                 Texas  -26.121174
# 44          Pennsylvania  -26.507598
# 45             Tennessee  -29.189583
# 46        North Carolina  -30.083985
# 47              Colorado  -35.867351
# 48                  Ohio  -36.186304

# %% [markdown]
# As above Table We see 39 to 48 number's city,In city company face the maximum loss

# %%
sns.pairplot(df, kind="reg")  
plt.show()

# %%
GP=df.groupby(['Country','State','City','Postal Code','Segment','Region','Category','Sub-Category'])
GP.first()
# Out:
#                                                                                                       Ship Mode  \
# Country       State     City       Postal Code Segment     Region  Category        Sub-Category
# United States Alabama   Auburn     36830       Consumer    South   Furniture       Chairs        Standard Class
#                                                                    Office Supplies Envelopes       Second Class
#                                                                                    Labels          Second Class
#                                                                                    Paper         Standard Class
#                                                                                    Storage       Standard Class
# ...                                                                                                         ...
#               Wisconsin Wausau     54401       Consumer    Central Office Supplies Binders       Standard Class
#                                                                                    Storage       Standard Class
#                         West Allis 53214       Corporate   Central Furniture       Bookcases       Second Class
#                                                                    Office Supplies Binders         Second Class
#               Wyoming   Cheyenne   82001       Home Office West    Furniture       Chairs        Standard Class
#
#                                                                                                     Sales  \
# Country       State     City       Postal Code Segment     Region  Category        Sub-Category
# United States Alabama   Auburn     36830       Consumer    South   Furniture       Chairs         350.980
#                                                                    Office Supplies Envelopes        7.380
#                                                                                    Labels         491.550
#                                                                                    Paper           13.080
#                                                                                    Storage        900.080
# ...                                                                                                   ...
#               Wisconsin Wausau     54401       Consumer    Central Office Supplies Binders         12.390
#                                                                                    Storage         36.630
#                         West Allis 53214       Corporate   Central Furniture       Bookcases      241.960
#                                                                    Office Supplies Binders          8.520
#               Wyoming   Cheyenne   82001       Home Office West    Furniture       Chairs        1603.136
#
#                                                                                                  Quantity  \
# Country       State     City       Postal Code Segment     Region  Category        Sub-Category
# United States Alabama   Auburn     36830       Consumer    South   Furniture       Chairs               1
#                                                                    Office Supplies Envelopes            2
#                                                                                    Labels               5
#                                                                                    Paper                2
#                                                                                    Storage              4
# ...                                                                                                   ...
#               Wisconsin Wausau     54401       Consumer    Central Office Supplies Binders              3
#                                                                                    Storage              3
#                         West Allis 53214       Corporate   Central Furniture       Bookcases            2
#                                                                    Office Supplies Binders              3
#               Wyoming   Cheyenne   82001       Home Office West    Furniture       Chairs               4
#
#                                                                                                  Discount  \
# Country       State     City       Postal Code Segment     Region  Category        Sub-Category
# United States Alabama   Auburn     36830       Consumer    South   Furniture       Chairs             0.0
#                                                                    Office Supplies Envelopes          0.0
#                                                                                    Labels             0.0
#                                                                                    Paper              0.0
#                                                                                    Storage            0.0
# ...                                                                                                   ...
#               Wisconsin Wausau     54401       Consumer    Central Office Supplies Binders            0.0
#                                                                                    Storage            0.0
#                         West Allis 53214       Corporate   Central Furniture       Bookcases          0.0
#                                                                    Office Supplies Binders            0.0
#               Wyoming   Cheyenne   82001       Home Office West    Furniture       Chairs             0.2
#
#                                                                                                    Profit
# Country       State     City       Postal Code Segment     Region  Category        Sub-Category
# United States Alabama   Auburn     36830       Consumer    South   Furniture       Chairs         84.2352
#                                                                    Office Supplies Envelopes       3.3948
#                                                                                    Labels        240.8595
#                                                                                    Paper           6.0168
#                                                                                    Storage       117.0104
# ...                                                                                                   ...
#               Wisconsin Wausau     54401       Consumer    Central Office Supplies Binders         5.8233
#                                                                                    Storage         9.8901
#                         West Allis 53214       Corporate   Central Furniture       Bookcases      24.1960
#                                                                    Office Supplies Binders         4.1748
#               Wyoming   Cheyenne   82001       Home Office West    Furniture       Chairs        100.1960
#
# [5346 rows x 5 columns]

# %% [markdown]
# Above table help to understand all data in simple way via groupby function
